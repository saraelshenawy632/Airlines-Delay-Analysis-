# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\Hp\Desktop\Orders.xlsx",skiprows=4)

# %%
df
# Out:
#        Order ID           Order Date               Country        City Branch  \
# 0           1.0  2023-01-01 00:00:00                 Syria        homs   hs01
# 1           2.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd01
# 2           3.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd03
# 3           NaN                  NaN                   NaN         NaN    NaN
# 4           4.0  2023-01-01 00:00:00  United Arab Emirates   abu dhabi   ad01
# ...         ...                  ...                   ...         ...    ...
# 19999   19996.0  2023-01-09 00:00:00               Morocco  casablanca   cs01
# 20000   19997.0  2023-01-09 00:00:00                 Syria        homs   hs01
# 20001   19998.0  2023-01-09 00:00:00                   USA   las vegas   lv01
# 20002   19999.0  2023-01-09 00:00:00          Saudi Arabia      jeddah   jd03
# 20003   20000.0  2023-01-09 00:00:00                   USA  washington   wh01
#
# ...

# %%
df.dropna(how="all",inplace=True)

# %%
df
# Out:
#        Order ID           Order Date               Country        City Branch  \
# 0           1.0  2023-01-01 00:00:00                 Syria        homs   hs01
# 1           2.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd01
# 2           3.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd03
# 4           4.0  2023-01-01 00:00:00  United Arab Emirates   abu dhabi   ad01
# 5           5.0  2023-01-01 00:00:00                   USA  washington   wh01
# ...         ...                  ...                   ...         ...    ...
# 19999   19996.0  2023-01-09 00:00:00               Morocco  casablanca   cs01
# 20000   19997.0  2023-01-09 00:00:00                 Syria        homs   hs01
# 20001   19998.0  2023-01-09 00:00:00                   USA   las vegas   lv01
# 20002   19999.0  2023-01-09 00:00:00          Saudi Arabia      jeddah   jd03
# 20003   20000.0  2023-01-09 00:00:00                   USA  washington   wh01
#
# ...

# %%
df.dropna();

# %%
df
# Out:
#        Order ID           Order Date               Country        City Branch  \
# 0           1.0  2023-01-01 00:00:00                 Syria        homs   hs01
# 1           2.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd01
# 2           3.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd03
# 4           4.0  2023-01-01 00:00:00  United Arab Emirates   abu dhabi   ad01
# 5           5.0  2023-01-01 00:00:00                   USA  washington   wh01
# ...         ...                  ...                   ...         ...    ...
# 19999   19996.0  2023-01-09 00:00:00               Morocco  casablanca   cs01
# 20000   19997.0  2023-01-09 00:00:00                 Syria        homs   hs01
# 20001   19998.0  2023-01-09 00:00:00                   USA   las vegas   lv01
# 20002   19999.0  2023-01-09 00:00:00          Saudi Arabia      jeddah   jd03
# 20003   20000.0  2023-01-09 00:00:00                   USA  washington   wh01
#
# ...

# %%
df.dropna(axis=1)
# Out:
#        Order ID           Order Date               Country        City Branch  \
# 0           1.0  2023-01-01 00:00:00                 Syria        homs   hs01
# 1           2.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd01
# 2           3.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd03
# 4           4.0  2023-01-01 00:00:00  United Arab Emirates   abu dhabi   ad01
# 5           5.0  2023-01-01 00:00:00                   USA  washington   wh01
# ...         ...                  ...                   ...         ...    ...
# 19999   19996.0  2023-01-09 00:00:00               Morocco  casablanca   cs01
# 20000   19997.0  2023-01-09 00:00:00                 Syria        homs   hs01
# 20001   19998.0  2023-01-09 00:00:00                   USA   las vegas   lv01
# 20002   19999.0  2023-01-09 00:00:00          Saudi Arabia      jeddah   jd03
# 20003   20000.0  2023-01-09 00:00:00                   USA  washington   wh01
#
# ...

# %%
df.dropna(inplace=True);

# %%
df
# Out:
#        Order ID           Order Date               Country        City Branch  \
# 0           1.0  2023-01-01 00:00:00                 Syria        homs   hs01
# 1           2.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd01
# 4           4.0  2023-01-01 00:00:00  United Arab Emirates   abu dhabi   ad01
# 5           5.0  2023-01-01 00:00:00                   USA  washington   wh01
# 6           6.0  2023-01-01 00:00:00                 Syria      aleppo   al01
# ...         ...                  ...                   ...         ...    ...
# 19999   19996.0  2023-01-09 00:00:00               Morocco  casablanca   cs01
# 20000   19997.0  2023-01-09 00:00:00                 Syria        homs   hs01
# 20001   19998.0  2023-01-09 00:00:00                   USA   las vegas   lv01
# 20002   19999.0  2023-01-09 00:00:00          Saudi Arabia      jeddah   jd03
# 20003   20000.0  2023-01-09 00:00:00                   USA  washington   wh01
#
# ...

# %%
df.dropna(how='all',inplace=True)

# %%
df
# Out:
#        Order ID           Order Date               Country        City Branch  \
# 0           1.0  2023-01-01 00:00:00                 Syria        homs   hs01
# 1           2.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd01
# 4           4.0  2023-01-01 00:00:00  United Arab Emirates   abu dhabi   ad01
# 5           5.0  2023-01-01 00:00:00                   USA  washington   wh01
# 6           6.0  2023-01-01 00:00:00                 Syria      aleppo   al01
# ...         ...                  ...                   ...         ...    ...
# 19999   19996.0  2023-01-09 00:00:00               Morocco  casablanca   cs01
# 20000   19997.0  2023-01-09 00:00:00                 Syria        homs   hs01
# 20001   19998.0  2023-01-09 00:00:00                   USA   las vegas   lv01
# 20002   19999.0  2023-01-09 00:00:00          Saudi Arabia      jeddah   jd03
# 20003   20000.0  2023-01-09 00:00:00                   USA  washington   wh01
#
# ...

# %%
df.describe()
# Out:
#            Order ID           Lat           Lng      Quantity    Unit Price  \
# count  18889.000000  18889.000000  18889.000000  18889.000000  18889.000000
# mean    9997.106623     30.441046     11.431530      1.939859    609.999524
# std     5774.960701      8.130648     53.149901      2.292993    621.149432
# min        1.000000     18.231100   -115.149200      1.000000     29.000000
# 25%     4985.000000     24.453900      2.352200      1.000000    179.000000
# 50%    10006.000000     27.180900     37.134300      1.000000    399.000000
# 75%    14996.000000     36.202100     42.500400      2.000000    899.000000
# max    20000.000000     48.856600     56.324200     13.000000   3999.000000
#
#            Discount        Status
# count  18889.000000  18889.000000
# mean      65.021528      0.701202
# std      145.481646      0.457743
# min        0.290000      0.000000
# 25%        9.800000      0.000000
# 50%       23.980000      1.000000
# 75%       64.900000      1.000000
# ...

# %%
df.shape
# Out:
# (18889, 19)

# %%
import numpy as np

arr = np.array([10, 20, 30, 40])
result = np.where(arr > 20, 'big', 'small')
print(result)
# Out:
# ['small' 'small' 'big' 'big']

# %%
import numpy as np

# %%
df
# Out:
#        Order ID           Order Date               Country        City Branch  \
# 0           1.0  2023-01-01 00:00:00                 Syria        homs   hs01
# 1           2.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd01
# 4           4.0  2023-01-01 00:00:00  United Arab Emirates   abu dhabi   ad01
# 5           5.0  2023-01-01 00:00:00                   USA  washington   wh01
# 6           6.0  2023-01-01 00:00:00                 Syria      aleppo   al01
# ...         ...                  ...                   ...         ...    ...
# 19999   19996.0  2023-01-09 00:00:00               Morocco  casablanca   cs01
# 20000   19997.0  2023-01-09 00:00:00                 Syria        homs   hs01
# 20001   19998.0  2023-01-09 00:00:00                   USA   las vegas   lv01
# 20002   19999.0  2023-01-09 00:00:00          Saudi Arabia      jeddah   jd03
# 20003   20000.0  2023-01-09 00:00:00                   USA  washington   wh01
#
# ...

# %%
df.to_excel(r"C:\Users\Hp\Desktop\New folder\data.xlsx", index=False)

# %%
df["Phone Number"].str.slice(4)
# Out:
# 0         5634962795
# 1         5311455624
# 4         5783343440
# 5         5352774687
# 6         5277356213
#             ...
# 19999     5880578642
# 20000     5286384144
# 20001     5463888674
# 20002     5931562498
# 20003     5338549800
# Name: Phone Number, Length: 18889, dtype: object

# %%
df
# Out:
#        Order ID           Order Date               Country        City Branch  \
# 0           1.0  2023-01-01 00:00:00                 Syria        homs   hs01
# 1           2.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd01
# 4           4.0  2023-01-01 00:00:00  United Arab Emirates   abu dhabi   ad01
# 5           5.0  2023-01-01 00:00:00                   USA  washington   wh01
# 6           6.0  2023-01-01 00:00:00                 Syria      aleppo   al01
# ...         ...                  ...                   ...         ...    ...
# 19999   19996.0  2023-01-09 00:00:00               Morocco  casablanca   cs01
# 20000   19997.0  2023-01-09 00:00:00                 Syria        homs   hs01
# 20001   19998.0  2023-01-09 00:00:00                   USA   las vegas   lv01
# 20002   19999.0  2023-01-09 00:00:00          Saudi Arabia      jeddah   jd03
# 20003   20000.0  2023-01-09 00:00:00                   USA  washington   wh01
#
# ...

# %%
df["Phone Number"]=df["Phone Number"].str.slice(start=4)

# %%
df
# Out:
#        Order ID           Order Date               Country        City Branch  \
# 0           1.0  2023-01-01 00:00:00                 Syria        homs   hs01
# 1           2.0  2023-01-01 00:00:00          Saudi Arabia      riyadh   rd01
# 4           4.0  2023-01-01 00:00:00  United Arab Emirates   abu dhabi   ad01
# 5           5.0  2023-01-01 00:00:00                   USA  washington   wh01
# 6           6.0  2023-01-01 00:00:00                 Syria      aleppo   al01
# ...         ...                  ...                   ...         ...    ...
# 19999   19996.0  2023-01-09 00:00:00               Morocco  casablanca   cs01
# 20000   19997.0  2023-01-09 00:00:00                 Syria        homs   hs01
# 20001   19998.0  2023-01-09 00:00:00                   USA   las vegas   lv01
# 20002   19999.0  2023-01-09 00:00:00          Saudi Arabia      jeddah   jd03
# 20003   20000.0  2023-01-09 00:00:00                   USA  washington   wh01
#
# ...

# %%
df["Unit Price"].sum()
# Out:
# np.float64(11522281.0)

# %%
df["Unit Price"].agg(["sum","count","mean"])
# Out:
# sum      1.152228e+07
# count    1.888900e+04
# mean     6.099995e+02
# Name: Unit Price, dtype: float64

# %%
pd.set_option("display.float_format", "{:,.2f}".format)

df["Unit Price"].agg(["sum", "count", "mean"])
# Out:
# sum     11,522,281.00
# count       18,889.00
# mean           610.00
# Name: Unit Price, dtype: float64

# %%
df.groupby(["Category", "Sub Category"])[["Unit Price", "Quantity"]].agg(["sum", "count"])
# Out:
#                                   Unit Price       Quantity
#                                          sum count      sum count
# Category       Sub Category
# Digital Camera Canon EOS          309,086.00   214   409.00   214
#                Canon EOS R Series 548,292.00   208   404.00   208
#                Fujifilm X Series  355,370.00   230   413.00   230
#                Nikon Coolpix      122,055.00   195   372.00   195
#                Nikon Z Series     321,197.00   203   363.00   203
# ...                                      ...   ...      ...   ...
# VR Headset     Oculus Rift S       49,900.00   100   150.00   100
#                Pimax Vision       290,500.00   300   611.00   300
#                Samsung Odyssey    172,385.00   115   218.00   115
#                Sony PlayStation    26,013.00    87   154.00    87
#                Valve Index        209,609.00   191   375.00   191
#
# [81 rows x 4 columns]

# %%
df.plot(x="Category",y="Unit Price",rot=45,color='g')
# Out:
# <Axes: xlabel='Category'>

# %%
import matplotlib.pyplot as plt
